# %%
import pynbody
from pynbody.analysis import profile
import matplotlib.pylab as plt
import numpy as np
import astropy.units as u
from astropy.io import ascii
from astropy.table import Table
import pandas as pd
# %matplotlib inline
from analyze_sumfiles import get_sumfile

# %%
datpath_k = "/home/michele/sim/MySimulations/Moria8Gyr_tidal/results/sumfiles/69002.dat"
datpath = "/home/michele/sim/MoRIA/results/sumfiles/69002.dat"

# %%
a = get_sumfile(datpath)
k = get_sumfile(datpath_k)

# %%
a
# Out:
# <Table length=165>
#   nr     time    redshift   ngas   nstar ...  DM<5Re  DM<10Re DM<30Re DM_all
#       kpc s / km                         ...
# int64  float64   float64  float64  int64 ... float64  float64 float64 int64
# ----- ---------- -------- -------- ----- ... -------- ------- ------- ------
#     0        5.0   1.1565 928930.0  6580 ...  0.05244 0.11811 0.26366      1
#     1        5.0   1.1637 928930.0  6580 ... 0.052444 0.11811 0.26366      1
#     2       5.05   1.1492 928880.0  6626 ... 0.052106 0.11225 0.26478      1
#     3        5.1   1.1349 928790.0  6717 ... 0.049436 0.10806 0.26688      1
#     4       5.15   1.1208 928730.0  6778 ... 0.048017 0.10655 0.26801      1
#     5        5.2   1.1069 928650.0  6856 ... 0.046636 0.10585 0.26942      1
#     6       5.25   1.0932 928600.0  6909 ... 0.044897 0.10453 0.27013      1
#     7        5.3   1.0798 928550.0  6961 ... 0.044956 0.10366 0.27099      1
#     8       5.35   1.0664 928450.0  7059 ... 0.045652 0.10335   0.272      1
#   ...        ...      ...      ...   ... ...      ...     ...     ...    ...
#   155       12.7 0.052647 900840.0 34666 ... 0.047652 0.11701 0.31737      1
#   156      12.75 0.048802 900640.0 34865 ... 0.048323  0.1166 0.31819      1
#   157       12.8 0.044979 900440.0 35075 ... 0.048668 0.11777 0.31818      1
#   158      12.85 0.041175 900150.0 35357 ... 0.050041  0.1178 0.31741      1
#   159       12.9 0.037391 899930.0 35583 ... 0.049877 0.11763  0.3171      1
#   160      12.95 0.033628 899700.0 35810 ... 0.049935 0.11745 0.31691      1
#   161       13.0 0.029884 899560.0 35947 ... 0.049905 0.11736 0.31663      1
#   162      13.05 0.026159 899240.0 36270 ... 0.049553 0.11775 0.31683      1
#   163       13.1 0.022455 898870.0 36642 ...  0.04998 0.11726 0.31713      1
#   164     13.133 0.020056 898750.0 36757 ... 0.049837  0.1175 0.31688      1

# %%
# fig, (ax1, ax2) = plt.subplots(2)
# ax1.plot(a.time, a.r_e_M)
# ax2.plot(k.time, k.r_e_M)

# %%
def plot_property(a, k, prop, unit=None, ax=None):
    if ax is None:
        fig, ax = plt.subplots()
    if unit is None:
        unit = k[prop].unit
    time = a['time'].to(u.Gyr)
    ax.plot(time, a[prop].to(unit), "r", label="MoRIA")
    k2 = np.interp(a['time'], k['time'], k[prop].to(unit), left=np.nan)
    ax.plot(time[:-1], k2[:-1], label="Kicked")
    ax.set_xlabel('time (Gyr)')
    if unit is not u.dimensionless_unscaled:
        ax.set_ylabel("{0} ({1:latex})".format(prop,unit))
    else:
        ax.set_ylabel("{0}".format(prop))
    ax.set_title(prop)
    plt.legend(loc=0)

# %%
# k[['time','SFR', 'Mstar']]

# %%
# fig, axes = plt.subplots(nrows=2, ncols=2)

# %%
plot_property(a, k, 'SFR')
plot_property(a, k, 'Mstar', u.Msun)
plot_property(a, k, 'r_e_M')
plot_property(a, k, 'MHI', u.Msun)
plot_property(a, k, 'Mgas_re', u.Msun)

# %%
plot_property(a, k, 'L_x', u.kg*u.km**2/u.s)
plot_property(a, k, 'L_y', u.kg*u.km**2/u.s)
plot_property(a, k, 'L_z', u.kg*u.km**2/u.s)

# %%
plot_property(a, k, 'metall_star')
plot_property(a, k, 'FeH_star')
plot_property(a, k, 'MgFe_star')
plot_property(a, k, 'metall_lum')
plot_property(a, k, 'FeH_lum')
plot_property(a, k, 'age_lum')

# %%
plot_property(a, k, 'velDisp_star')
plot_property(a, k, 'velDisp_DM')

# %%
fig, ax = plt.subplots()
ax.plot(k['rcom_x'], k['rcom_y'])
ax.set_aspect('equal')
